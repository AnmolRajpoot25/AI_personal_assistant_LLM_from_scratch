# %% [markdown]
# <a href="https://colab.research.google.com/github/AnmolRajpoot25/AI_personal_assistant_LLM_from_scratch/blob/master/AI_personal_assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q tiktoken torch torchvision torchaudio
# !pip install -q fastapi uvicorn pyngrok nest-asyncio
# !pip install -q requests tqdm matplotlib
print('✅ Dependencies installed.')
# Out:
# ✅ Dependencies installed.

# %% [markdown]
# ## Step 1 — Clone Your GitHub Repo

# %%
import os

REPO_URL   = "https://github.com/AnmolRajpoot25/AI_personal_assistant_LLM_from_scratch"
REPO_NAME  = "AI_personal_assistant_LLM_from_scratch"
WORK_DIR   = f"/content/{REPO_NAME}"

# ── If repo is PRIVATE, replace REPO_URL with the token version below ──
# GITHUB_TOKEN = "ghp_your_token_here"   # <-- personal access token
# REPO_URL = f"https://{GITHUB_TOKEN}@github.com/AnmolRajpoot25/AI_personal_assistant_LLM_from_scratch"

if os.path.exists(WORK_DIR):
    print("Repo already cloned — pulling latest...")
    # !cd {WORK_DIR} && git pull
else:
    print(f"Cloning {REPO_URL} ...")
    # !git clone {REPO_URL} {WORK_DIR}

os.chdir(WORK_DIR)
print(f"\n✅ Working directory: {os.getcwd()}")
print("\n📁 Repo contents:")
# !ls -la
# Out:
# Cloning https://github.com/AnmolRajpoot25/AI_personal_assistant_LLM_from_scratch ...
# Cloning into '/content/AI_personal_assistant_LLM_from_scratch'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 84 (delta 27), reused 82 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (84/84), 728.21 KiB | 2.70 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
#
# ✅ Working directory: /content/AI_personal_assistant_LLM_from_scratch
#
# 📁 Repo contents:
# total 680
# drwxr-xr-x 8 root root   4096 Apr  8 21:44 .
# drwxr-xr-x 1 root root   4096 Apr  8 21:44 ..
# drwxr-xr-x 8 root root   4096 Apr  8 21:44 .git
# -rw-r--r-- 1 root root     28 Apr  8 21:44 .gitignore
# -rw-r--r-- 1 root root   3616 Apr  8 21:44 gpt_download.py
# drwxr-xr-x 3 root root   4096 Apr  8 21:44 .idea
# -rw-r--r-- 1 root root 203524 Apr  8 21:44 instruction-data.json
# ...

# %% [markdown]
# ## Step 2 — Install Dependencies

# %%
# Install from requirements.txt if it exists, else install manually
import os

if os.path.exists("requirements.txt"):
    print("Found requirements.txt — installing...")
    # !pip install -q -r requirements.txt
else:
    print("No requirements.txt found — installing standard dependencies...")

# Always ensure these are present
# !pip install -q tiktoken torch torchvision
# !pip install -q fastapi uvicorn pyngrok nest-asyncio
# !pip install -q requests tqdm matplotlib

print("\n✅ All dependencies installed.")
# Out:
# No requirements.txt found — installing standard dependencies...
#
# ✅ All dependencies installed.

# %% [markdown]
# ## Step 3 — Auto-detect Repo Structure & Locate Key Files

# %%
import os, glob

print("=" * 50)
print("📂 Full repo structure:")
print("=" * 50)
for root, dirs, files in os.walk("."):
    # Skip hidden folders and __pycache__
    dirs[:] = [d for d in dirs if not d.startswith('.') and d != '__pycache__']
    level = root.replace('.', '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 2 * (level + 1)
    for file in files:
        print(f'{subindent}{file}')

print("\n" + "=" * 50)
print("🔍 Looking for key files...")
print("=" * 50)

# Search for the important files
py_files    = glob.glob('**/*.py',    recursive=True)
ipynb_files = glob.glob('**/*.ipynb', recursive=True)
json_files  = glob.glob('**/*.json',  recursive=True)
pth_files   = glob.glob('**/*.pth',   recursive=True)

print(f"\n🐍 Python files ({len(py_files)}):")
for f in py_files: print(f"   {f}")

print(f"\n📓 Notebooks ({len(ipynb_files)}):")
for f in ipynb_files: print(f"   {f}")

print(f"\n📄 JSON files ({len(json_files)}):")
for f in json_files: print(f"   {f}")

print(f"\n💾 Saved models ({len(pth_files)}):")
for f in pth_files: print(f"   {f}")
# Out:
# ...
# 📂 Full repo structure:
# ...
# ./
#   test.csv
#   .gitignore
#   instruction-data-with-response.json
#   train.csv
#   previous_chapters.py
#   instruction-data.json
#   validation.csv
#   sms_spam_collection.zip
#   the-verdict.txt
#   readme.md
#   gpt_download.py
#   notebooks/
#     Pretraing_model_on_unlabeled_data.ipynb
#     finetuning_of_LLM_models_and_use_as_spam_classifier.ipynb
#     AI_personal_trainer_using_LLMs.ipynb
#     tokenization_of_data_for_LLM_processing.ipynb
#     attention_mechanism_with_and_without_training_weights.ipynb
#     GPT_implementation_from_scratch_to_generate_text.ipynb
#   sms_spam_collection/
#     .gitignore
#     SMSSpamCollection.tsv
#     readme
#   outputs/
#     loss-plot.pdf
#
# ...
# 🔍 Looking for key files...
# ...
#
# 🐍 Python files (2):
#    previous_chapters.py
#    gpt_download.py
#
# 📓 Notebooks (6):
#    notebooks/Pretraing_model_on_unlabeled_data.ipynb
#    notebooks/finetuning_of_LLM_models_and_use_as_spam_classifier.ipynb
# ...

# %% [markdown]
# ## Step 4 — Download Required Helper Files
#
# The GPT-2 download and model utilities come from the `LLMs-from-scratch` repo.
# This cell is smart — it only downloads what's missing from your repo.

# %%
import urllib.request, os, glob

BASE_RAW = "https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/main"

REQUIRED_FILES = {
    "gpt_download.py"    : f"{BASE_RAW}/ch05/01_main-chapter-code/gpt_download.py",
    "previous_chapters.py": f"{BASE_RAW}/ch07/01_main-chapter-code/previous_chapters.py",
    "instruction-data.json": f"{BASE_RAW}/ch07/01_main-chapter-code/instruction-data.json",
}

for fname, url in REQUIRED_FILES.items():
    # Search recursively in case file exists somewhere in the repo
    existing = glob.glob(f'**/{fname}', recursive=True)
    if existing:
        print(f"✅ Found in repo: {existing[0]}")
        # Copy to working dir root for easy imports
        if not os.path.exists(fname):
            import shutil
            shutil.copy(existing[0], fname)
            print(f"   Copied to root: {fname}")
    else:
        print(f"⬇️  Downloading {fname}...")
        try:
            urllib.request.urlretrieve(url, fname)
            print(f"   ✅ Downloaded {fname}")
        except Exception as e:
            print(f"   ❌ Failed: {e}")

print("\n✅ All required files ready.")
# Out:
# ✅ Found in repo: gpt_download.py
# ✅ Found in repo: previous_chapters.py
# ✅ Found in repo: instruction-data.json
#
# ✅ All required files ready.

# %%
## Step 5 — Prepare Dataset & DataLoaders

# %%
import json, torch, tiktoken
from functools import partial
from torch.utils.data import Dataset, DataLoader

# ── Load instruction data ──────────────────────────────────────────────
with open("instruction-data.json", "r") as f:
    data = json.load(f)

print(f"✅ Loaded {len(data)} instruction entries")
print(f"\nSample entry:\n{json.dumps(data[0], indent=2)}")
# Out:
# ✅ Loaded 1100 instruction entries
#
# Sample entry:
# {
#   "instruction": "Evaluate the following phrase by transforming it into the spelling given.",
#   "input": "freind --> friend",
#   "output": "The spelling of the given phrase \"freind\" is incorrect, the correct spelling is \"friend\"."
# }

# %%
# ── Train / Val / Test split ───────────────────────────────────────────
train_portion = int(len(data) * 0.85)
test_portion  = int(len(data) * 0.10)
train_data = data[:train_portion]
test_data  = data[train_portion : train_portion + test_portion]
val_data   = data[train_portion + test_portion :]

print(f"Train: {len(train_data)} | Val: {len(val_data)} | Test: {len(test_data)}")

# ── Tokenizer ─────────────────────────────────────────────────────────
tokenizer = tiktoken.get_encoding("gpt2")

# ── Alpaca-style prompt formatter ─────────────────────────────────────
def format_input(entry):
    instruction_text = (
        "Below is an instruction that describes a task. "
        "Write a response that appropriately completes the request."
        f"\n\n### Instruction:\n{entry['instruction']}"
    )
    input_text = f"\n\n### Input:\n{entry['input']}" if entry["input"] else ""
    return instruction_text + input_text

# ── Collate function with padding mask ────────────────────────────────
def custom_collate_fn(
        batch, pad_token_id=50256, ignore_index=-100,
        allowed_max_length=None, device="cpu"):
    batch_max_length = max(len(item) + 1 for item in batch)
    inputs_lst, targets_lst = [], []
    for item in batch:
        new_item = item.copy() + [pad_token_id]
        padded   = new_item + [pad_token_id] * (batch_max_length - len(new_item))
        inputs   = torch.tensor(padded[:-1])
        targets  = torch.tensor(padded[1:])
        mask     = targets == pad_token_id
        indices  = torch.nonzero(mask).squeeze()
        if indices.numel() > 1:
            targets[indices[1:]] = ignore_index
        if allowed_max_length is not None:
            inputs  = inputs[:allowed_max_length]
            targets = targets[:allowed_max_length]
        inputs_lst.append(inputs)
        targets_lst.append(targets)
    return (torch.stack(inputs_lst).to(device),
            torch.stack(targets_lst).to(device))

# ── Dataset class ─────────────────────────────────────────────────────
class InstructionDataset(Dataset):
    def __init__(self, data, tokenizer):
        self.encoded_texts = [
            tokenizer.encode(
                format_input(e) + f"\n\n### Response:\n{e['output']}"
            )
            for e in data
        ]
    def __getitem__(self, idx): return self.encoded_texts[idx]
    def __len__(self):          return len(self.encoded_texts)

# ── Device & DataLoaders ───────────────────────────────────────────────
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")
collate_fn = partial(custom_collate_fn, device=device, allowed_max_length=1024)

torch.manual_seed(123)
BATCH_SIZE = 4   # reduce to 2 if you get CUDA OOM

train_loader = DataLoader(InstructionDataset(train_data, tokenizer),
    batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=True,  drop_last=True)
val_loader   = DataLoader(InstructionDataset(val_data,   tokenizer),
    batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=False, drop_last=False)

print(f"\n✅ Device       : {device}")
print(f"   Train batches: {len(train_loader)}")
print(f"   Val batches  : {len(val_loader)}")
# Out:
# Train: 935 | Val: 55 | Test: 110
#
# ✅ Device       : cuda
#    Train batches: 233
#    Val batches  : 14

# %% [markdown]
# ## Step 6 — Load GPT-2 Medium & Fine-tune
#
# > Downloads ~1.4 GB of pretrained weights, then fine-tunes for 2 epochs (~25–40 min on T4 GPU)

# %%
from gpt_download import download_and_load_gpt2
from previous_chapters import GPTModel, load_weights_into_gpt

BASE_CONFIG = {
    "vocab_size"    : 50257,
    "context_length": 1024,
    "drop_rate"     : 0.0,
    "qkv_bias"      : True,
    # GPT-2 medium (355M)
    "emb_dim"  : 1024,
    "n_layers" : 24,
    "n_heads"  : 16,
}

print("⬇️  Downloading GPT-2 medium weights (~1.4 GB)...")
settings, params = download_and_load_gpt2(model_size="355M", models_dir="gpt2")

model = GPTModel(BASE_CONFIG)
load_weights_into_gpt(model, params)
model.eval()
model.to(device)

total_params = sum(p.numel() for p in model.parameters())
print(f"\n✅ GPT-2 medium loaded")
print(f"   Parameters  : {total_params:,}")
print(f"   Device      : {device}")
# Out:
# ⬇️  Downloading GPT-2 medium weights (~1.4 GB)...
# checkpoint: 100%|██████████| 77.0/77.0 [00:00<00:00, 90.5kiB/s]
# encoder.json: 100%|██████████| 1.04M/1.04M [00:01<00:00, 749kiB/s]
# hparams.json: 100%|██████████| 91.0/91.0 [00:00<00:00, 175kiB/s]
# model.ckpt.data-00000-of-00001: 100%|██████████| 1.42G/1.42G [06:30<00:00, 3.63MiB/s]
# model.ckpt.index: 100%|██████████| 10.4k/10.4k [00:00<00:00, 23.1MiB/s]
# model.ckpt.meta: 100%|██████████| 927k/927k [00:01<00:00, 572kiB/s]
# vocab.bpe: 100%|██████████| 456k/456k [00:01<00:00, 455kiB/s]
# ✅ GPT-2 medium loaded
#    Parameters  : 406,286,336
#    Device      : cuda

# %%
import time
from previous_chapters import calc_loss_loader, train_model_simple

torch.manual_seed(123)
optimizer  = torch.optim.AdamW(model.parameters(), lr=5e-5, weight_decay=0.1)
num_epochs = 2

print(f"Starting fine-tuning for {num_epochs} epochs...")
t0 = time.time()

train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context=format_input(val_data[0]),
    tokenizer=tokenizer
)

mins = (time.time() - t0) / 60
print(f"\n✅ Training complete in {mins:.1f} min")
print(f"   Final train loss: {train_losses[-1]:.4f}")
print(f"   Final val loss  : {val_losses[-1]:.4f}")
# Out:
# Starting fine-tuning for 2 epochs...
# Ep 1 (Step 000000): Train loss 2.623, Val loss 2.541
# Ep 1 (Step 000005): Train loss 1.246, Val loss 1.188
# Ep 1 (Step 000010): Train loss 0.835, Val loss 1.034
# Ep 1 (Step 000015): Train loss 0.876, Val loss 1.010
# Ep 1 (Step 000020): Train loss 0.821, Val loss 0.969
# Ep 1 (Step 000025): Train loss 0.812, Val loss 0.969
# Ep 1 (Step 000030): Train loss 0.761, Val loss 0.954
# Ep 1 (Step 000035): Train loss 0.891, Val loss 0.939
# Ep 1 (Step 000040): Train loss 0.788, Val loss 0.918
# Ep 1 (Step 000045): Train loss 0.680, Val loss 0.897
# Ep 1 (Step 000050): Train loss 0.736, Val loss 0.891
# Ep 1 (Step 000055): Train loss 0.787, Val loss 0.882
# Ep 1 (Step 000060): Train loss 0.794, Val loss 0.879
# Ep 1 (Step 000065): Train loss 0.714, Val loss 0.862
# Ep 1 (Step 000070): Train loss 0.581, Val loss 0.844
# Ep 1 (Step 000075): Train loss 0.611, Val loss 0.851
# Ep 1 (Step 000080): Train loss 0.671, Val loss 0.863
# ...

# %%
CKPT_PATH = "gpt2-medium-355M-personal-trainer.pth"
torch.save(model.state_dict(), CKPT_PATH)
print(f"✅ Model saved → {CKPT_PATH}")

from google.colab import drive
drive.mount('/content/drive')
import shutil
shutil.copy(CKPT_PATH, "/content/drive/MyDrive/personal_trainer.pth")
print("✅ Also saved to Google Drive")
# Out:
# ✅ Model saved → gpt2-medium-355M-personal-trainer.pth
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Also saved to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
model.load_state_dict(torch.load("/content/drive/MyDrive/personal_trainer.pth", map_location=device))

model.eval()
print(f"✅ Checkpoint loaded → {CKPT_PATH}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Checkpoint loaded → gpt2-medium-355M-personal-trainer.pth

# %%
from previous_chapters import generate, text_to_token_ids, token_ids_to_text

def generate_response(instruction: str, input_text: str = "",
                       max_new_tokens: int = 200) -> str:
    model.eval()
    entry  = {"instruction": instruction, "input": input_text}
    prompt = format_input(entry)
    token_ids = generate(
        model=model,
        idx=text_to_token_ids(prompt, tokenizer).to(device),
        max_new_tokens=max_new_tokens,
        context_size=BASE_CONFIG["context_length"],
        eos_id=50256,
    )
    generated = token_ids_to_text(token_ids, tokenizer)
    response  = generated[len(prompt):].replace("### Response:", "").strip()
    return response

# Quick test
test_questions = [
    "Suggest a simple 3-day workout plan for a beginner.",
    "What should I eat before a morning run?",
    "How many rest days per week are recommended?",
]

for q in test_questions:
    print(f"\n🧑 {q}")
    print(f"🤖 {generate_response(q, max_new_tokens=100)}")
    print("-" * 60)
# Out:
# 🧑 Suggest a simple 3-day workout plan for a beginner.
# 🤖 Here is a 3-day workout plan for a beginner:
# Day 1:
# Run 5 miles.
# Day 2:
# Run 5 miles.
# Day 3:
# Run 10 miles.
# ------------------------------------------------------------
#
# 🧑 What should I eat before a morning run?
# 🤖 The correct answer is "eat a fruit or vegetable."
# ------------------------------------------------------------
#
# 🧑 How many rest days per week are recommended?
# 🤖 The recommended number of rest days per week is 3.
# ------------------------------------------------------------

# %% [markdown]
# step 8 - build fastapi App

# %%
from fastapi import FastAPI
from fastapi.responses import HTMLResponse
from pydantic import BaseModel
from typing import Optional

app = FastAPI(
    title="AI Personal Trainer",
    description="GPT-2 medium fine-tuned — from AnmolRajpoot25/AI_personal_assistant_LLM_from_scratch",
    version="1.0.0",
)

class ChatRequest(BaseModel):
    instruction: str
    input: Optional[str] = ""
    max_tokens: Optional[int] = 256

class ChatResponse(BaseModel):
    response: str

# ── Chat UI ────────────────────────────────────────────────────────────
@app.get("/", response_class=HTMLResponse)
def home():
    return """
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8"/>
  <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
  <title>🏋️ AI Personal Trainer</title>
  <style>
    *{box-sizing:border-box;margin:0;padding:0}
    body{font-family:'Segoe UI',sans-serif;background:#0f172a;color:#e2e8f0;display:flex;flex-direction:column;height:100vh}
    header{background:#1e293b;padding:14px 22px;border-bottom:1px solid #334155;font-size:1.2rem;font-weight:700}
    header span{color:#38bdf8;font-size:.9rem;font-weight:400;margin-left:10px}
    #chat{flex:1;overflow-y:auto;padding:18px 22px;display:flex;flex-direction:column;gap:12px}
    .bubble{max-width:78%;padding:11px 15px;border-radius:12px;line-height:1.55;white-space:pre-wrap;font-size:.92rem}
    .user{background:#0369a1;align-self:flex-end;border-bottom-right-radius:2px}
    .bot{background:#1e293b;border:1px solid #334155;align-self:flex-start;border-bottom-left-radius:2px}
    .thinking{color:#94a3b8;font-style:italic}
    #form{display:flex;gap:10px;padding:14px 22px;background:#1e293b;border-top:1px solid #334155}
    textarea{flex:1;background:#0f172a;border:1px solid #334155;border-radius:8px;padding:9px 13px;color:#e2e8f0;font-size:.92rem;resize:none}
    button{background:#0369a1;color:#fff;border:none;border-radius:8px;padding:9px 18px;cursor:pointer;font-size:.92rem}
    button:hover{background:#0284c7}
    button:disabled{background:#334155;cursor:default}
    .badge{display:inline-block;background:#0c2d4a;color:#38bdf8;font-size:.7rem;padding:2px 8px;border-radius:10px;margin-left:8px;vertical-align:middle}
  </style>
</head>
<body>
  <header>🏋️ AI Personal Trainer <span class="badge">GPT-2 Medium · Fine-tuned</span></header>
  <div id="chat">
    <div class="bubble bot">👋 Hi! I'm your AI Personal Trainer built from scratch using GPT-2. Ask me about workouts, nutrition, recovery, or any fitness goal!</div>
  </div>
  <div id="form">
    <textarea id="inp" rows="2" placeholder="e.g. Give me a 4-week beginner gym plan..."
      onkeydown="if(event.key==='Enter'&&!event.shiftKey){event.preventDefault();send();}"></textarea>
    <button id="btn" onclick="send()">Send</button>
  </div>
  <script>
    async function send(){
      const inp=document.getElementById('inp'), chat=document.getElementById('chat'), btn=document.getElementById('btn');
      const text=inp.value.trim(); if(!text)return;
      inp.value=''; btn.disabled=true;
      chat.innerHTML+=`<div class="bubble user">${esc(text)}</div>`;
      const t=document.createElement('div'); t.className='bubble bot thinking'; t.textContent='Thinking...';
      chat.appendChild(t); chat.scrollTop=chat.scrollHeight;
      try{
        const r=await fetch('/chat',{method:'POST',headers:{'Content-Type':'application/json'},
          body:JSON.stringify({instruction:text,input:'',max_tokens:256})});
        const d=await r.json();
        t.className='bubble bot'; t.textContent=d.response||d.detail||'No response.';
      }catch(e){t.textContent='Error: '+e.message;}
      btn.disabled=false; chat.scrollTop=chat.scrollHeight;
    }
    function esc(s){return s.replace(/&/g,'&amp;').replace(/</g,'&lt;').replace(/>/g,'&gt;');}
  </script>
</body>
</html>
    """

# ── Inference endpoint ─────────────────────────────────────────────────
@app.post("/chat", response_model=ChatResponse)
def chat(req: ChatRequest):
    reply = generate_response(
        instruction=req.instruction,
        input_text=req.input or "",
        max_new_tokens=req.max_tokens,
    )
    return ChatResponse(response=reply)

# ── Health check ───────────────────────────────────────────────────────
@app.get("/health")
def health():
    import torch
    return {
        "status" : "ok",
        "device" : str(device),
        "repo"   : "AnmolRajpoot25/AI_personal_assistant_LLM_from_scratch",
        "model"  : "GPT-2 Medium 355M fine-tuned",
        "cuda"   : torch.cuda.is_available(),
    }

# ── Repo info endpoint ─────────────────────────────────────────────────
@app.get("/repo")
def repo_info():
    import subprocess
    try:
        commit = subprocess.check_output(
            ['git', 'log', '--oneline', '-5'], cwd=WORK_DIR
        ).decode().strip()
    except:
        commit = "unavailable"
    return {
        "repo"          : "AnmolRajpoot25/AI_personal_assistant_LLM_from_scratch",
        "recent_commits": commit
    }

print("✅ FastAPI app ready.")
print("   Endpoints: /  |  /chat  |  /health  |  /repo  |  /docs")
# Out:
# ✅ FastAPI app ready.
#    Endpoints: /  |  /chat  |  /health  |  /repo  |  /docs

# %%
# ── 👇 Paste your ngrok authtoken here ────────────────────────────────
NGROK_TOKEN = "3C5pHeE9ogQ3G3BFIlnd277IQih_3c7SQrY7XQ1scuWrd1Bye"
# ─────────────────────────────────────────────────────────────────────

import nest_asyncio, asyncio, uvicorn
from pyngrok import ngrok, conf

nest_asyncio.apply()  # patches the running loop to allow nesting

conf.get_default().auth_token = NGROK_TOKEN
ngrok.kill()

PORT = 8000
public_url = ngrok.connect(PORT, "http")

# Extract just the URL string from the NgrokTunnel object
url = public_url.public_url

print("\n" + "="*55)
print(f"  🌐 Public URL  : {url}")
print(f"  🏋️  Chat UI     : {url}/")
print(f"  📋 API Docs    : {url}/docs")
print(f"  💬 Chat API    : POST {url}/chat")
print(f"  🩺 Health      : {url}/health")
print(f"  📦 Repo Info   : {url}/repo")
print("="*55)
print("\n🚀 Starting server — share the URL above!\n")

# ✅ Use async config instead of uvicorn.run()
config = uvicorn.Config(app, host="0.0.0.0", port=PORT, log_level="info")
server = uvicorn.Server(config)
await server.serve()
# Out:
# ...
#   🌐 Public URL  : https://unphilosophical-jeff-gracelike.ngrok-free.dev
#   🏋️  Chat UI     : https://unphilosophical-jeff-gracelike.ngrok-free.dev/
#   📋 API Docs    : https://unphilosophical-jeff-gracelike.ngrok-free.dev/docs
#   💬 Chat API    : POST https://unphilosophical-jeff-gracelike.ngrok-free.dev/chat
#   🩺 Health      : https://unphilosophical-jeff-gracelike.ngrok-free.dev/health
#   📦 Repo Info   : https://unphilosophical-jeff-gracelike.ngrok-free.dev/repo
# ...
#
# 🚀 Starting server — share the URL above!
# INFO:     Started server process [709]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     2409:40c4:2142:72c9:e9d7:3b2:3db1:e8d0:0 - "GET / HTTP/1.1" 200 OK
# INFO:     2409:40c4:2142:72c9:e9d7:3b2:3db1:e8d0:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     2409:40c4:2142:72c9:e9d7:3b2:3db1:e8d0:0 - "POST /chat HTTP/1.1" 200 OK
# ...

# %% [markdown]
# Test the Live API (run in a separate cell)

# %%
import requests

# ── Paste your public ngrok URL from Step 9 ───────────────────────────
API_URL = "https://unphilosophical-jeff-gracelike.ngrok-free.dev/"

# Health check
print("Health:", requests.get(f"{API_URL}/health").json())

# Repo info
print("Repo:",   requests.get(f"{API_URL}/repo").json())

# Chat test
questions = [
    "Design a 3-day full body workout for a beginner.",
    "What macros should I eat on rest days?",
    "How do I improve my running stamina in 4 weeks?",
]

for q in questions:
    r = requests.post(f"{API_URL}/chat",
                      json={"instruction": q, "input": "", "max_tokens": 150})
    print(f"\n🧑 {q}")
    print(f"🤖 {r.json()['response']}")
    print("-" * 60)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#     975         try:
# --> 976             return complexjson.loads(self.text, **kwargs)
#     977         except JSONDecodeError as e:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     513             and not use_decimal and not allow_nan and not kw):
# --> 514         return _default_decoder.decode(s)
#     515     if cls is None:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     385             s = str(s, self.encoding)
# --> 386         obj, end = self.raw_decode(s)
#     387         end = _w(s, end).end()
#
# ...

# %% [markdown]
# # To shut down the ngrok server

# %%
from pyngrok import ngrok
ngrok.kill()
print("🛑 ngrok tunnel closed.")
